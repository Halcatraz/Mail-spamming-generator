# %%
#importation necessaire
import random
import subprocess
#difinition des variables de librairies, des chemins des fichiers necessaires
libraries = ['transformers', 'tensorflow']
file_path = "exp_entry.txt"
output_dir = "output"

#installation des librairies et importation des pacquages necessaires 
for lib in libraries:
    try:
        __import__(lib)
    except ImportError:
        subprocess.run(['pip', 'install', lib])
from transformers import AutoTokenizer, AutoModelForCausalLM

# Recuperation des potentielles entrées de l'IA
lines=[]
with open(file_path, 'r') as file:
    lines = file.read().split(sep='\n')

#recuperation du model (IA) et du tokenizer (il permet de decoupper une expression en mot séparer ou en lettre, ca dépend du concepteur de l'IA)
tokenizer = AutoTokenizer.from_pretrained(output_dir)
model = AutoModelForCausalLM.from_pretrained(output_dir)


# Tokeniser le texte d'entrée
input_ids = tokenizer.encode(random.choice(lines), return_tensors="pt")

# Faire des prédictions
output = model.generate(input_ids, max_length=50, num_return_sequences=1, temperature=0.7)

# Décoder les tokens générés en texte
decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)

# Afficher le texte généré
print(decoded_output)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained("Wikidepia/gpt2-spam")
model = AutoModelForCausalLM.from_pretrained("Wikidepia/gpt2-spam")

# %%
output_dir = "output"

# Enregistrer le tokenizer et le modèle dans le répertoire spécifié
tokenizer.save_pretrained(output_dir)
model.save_pretrained(output_dir)

# %%
input_text = a[4]

# Tokeniser le texte d'entrée
input_ids = tokenizer.encode(input_text, return_tensors="pt")

# Faire des prédictions
output = model.generate(input_ids, max_length=50, num_return_sequences=1, pad_token_id=50256)

# %%
# Décoder les tokens générés en texte
decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)

# Afficher le texte généré
print(decoded_output)
# Out:
# SIX chance to win $100,000 in $lix tokens. join now: https://wn.nr/jxjqx
# [SP] new airdrop: metamusk reward: $10 in $musk (

# %%
from datasets import load_dataset

dataset = load_dataset("SalehAhmad/Spam-Ham")

# %%
a=[]
for i in range (100):
    if dataset['train']['label'][i]=='spam':
        a.append(dataset['train']['sms_text'][i][:10])

a
# Out:
# ['Free entry',
#  'FreeMsg He',
#  'WINNER!! A',
#  'Had your m',
#  'SIX chance',
#  'URGENT! Yo',
#  'XXXMobileM',
#  'England v ',
#  'Thanks for',
#  '0773258435',
#  'SMS. ac Sp',
#  'Congrats! ',
#  'As a value',
#  'Urgent UR ',
#  'Did you he',
#  'Please cal',
#  'Your free ']

# %%
# Chemin vers le fichier texte de sortie
output_file = "exp_entry.txt"

# Écriture du contenu de la liste dans le fichier texte
with open(output_file, 'w') as file:
    for item in a:
        file.write("%s\n" % item)

# %%
# Chemin vers le fichier
file_path = "exp_entry.txt"
lines=[]

with open(file_path, 'r') as file:
    lines = file.read().split(sep='\n')

# Afficher le contenu du fichier
print(lines)
# Out:
# ['Free entry', 'FreeMsg He', 'WINNER!! A', 'Had your m', 'SIX chance', 'URGENT! Yo', 'XXXMobileM', 'England v ', 'Thanks for', '0773258435', 'SMS. ac Sp', 'Congrats! ', 'As a value', 'Urgent UR ', 'Did you he', 'Please cal', 'Your free ', '']

# %%
# Out:
# 'FreeMsg He'

# %%
type(file_content)
# Out:
# str

# %%
dataset['train']['label']
# Out:
# ['ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
# ...

# %%
dataset['train']['label']
# Out:
# ['ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'spam',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'ham',
#  'spam',
#  'ham',
#  'spam',
#  'ham',
#  'ham',
# ...
